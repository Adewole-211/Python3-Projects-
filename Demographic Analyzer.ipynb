# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
#na_values removes the values you do not want, header gets rid of the head
adult_df = pd.read_csv ("adult.data.csv", na_values = '?')
adult_df.isnull().sum() # sum up the missing values
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# salary               0
# dtype: int64

# %%
#now i want to check for duplicates
adult_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
adult_df.info #checking to see the numbers of row and columns
# Out:
# <bound method DataFrame.info of        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
adult_df.drop_duplicates(inplace=True) # the inplace=True, makes the drop permanent. remember this.
adult_df.info
# Out:
# <bound method DataFrame.info of        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
#as shown above it has gone from 32561 rows to 32537 rows, there were some duplicates after all, now i wish to get some general data around race
adult_df['race'].value_counts()
# Out:
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
# Now i am going to index the race column
adult_df.set_index('race', inplace=True)

# %%
adult_df # the race section as been indexed.
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# race
# White   39         State-gov   77516   Bachelors             13
# White   50  Self-emp-not-inc   83311   Bachelors             13
# White   38           Private  215646     HS-grad              9
# Black   53           Private  234721        11th              7
# Black   28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# White   27           Private  257302  Assoc-acdm             12
# White   40           Private  154374     HS-grad              9
# White   58           Private  151910     HS-grad              9
# White   22           Private  201490     HS-grad              9
# White   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship     sex  \
# race
# White       Never-married       Adm-clerical  Not-in-family    Male
# ...

# %%
adult_df.loc['Black'] # meaning that i can get all the data for a given race easily.
# Out:
#        age workclass  fnlwgt     education  education_num  \
# race
# Black   53   Private  234721          11th              7
# Black   28   Private  338409     Bachelors             13
# Black   49   Private  160187           9th              5
# Black   37   Private  280464  Some-college             10
# Black   32   Private  205019    Assoc-acdm             12
# ...    ...       ...     ...           ...            ...
# Black   33   Private  273243       HS-grad              9
# Black   22   Private  325033          12th              8
# Black   30   Private  345898       HS-grad              9
# Black   38   Private  139180     Bachelors             13
# Black   41       NaN  202822       HS-grad              9
#
#               marital_status         occupation   relationship     sex  \
# race
# Black     Married-civ-spouse  Handlers-cleaners        Husband    Male
# Black     Married-civ-spouse     Prof-specialty           Wife  Female
# ...

# %%
adult_df.index.value_counts() #due to it being an index, we need to use a different approach than just making a regular call.
# Out:
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
race_count = adult_df.index.value_counts() # what this does is it nestle it in a new pandas series that can be called upon at any moment

# %%
race_count # as shown here
# Out:
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
average_age_men = adult_df[adult_df['sex'] == 'Male']['age'].mean() # with this, i have created a pandas series, 
# it is looking eith the  adult_df data frames pecifically in the sex column and has selected males 
# and linked it to the age, i have then selected the avg

# %%
average_age_men # now i can call upon this at any point
# Out:
# np.float64(39.43605051664753)

# %%
adult_df['education'].value_counts() # this gives me the count of education levels
# Out:
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: count, dtype: int64

# %%
# But lets say i wish to get only the percentages, namely the percentage of people with a bachelors
#step one get the total as a pandas series 
total_edu = adult_df['education'].count()

# %%
total_edu #now we have the total
# Out:
# np.int64(32537)

# %%
bachelor_count = (adult_df['education'] == 'Bachelors').sum() #now following the same syntax as the race example.
# have added the total number of bachelors degrees and nested it in a new series

# %%
bachelor_count
# Out:
# np.int64(5353)

# %%
bachelor_percent = (bachelor_count / total_edu) * 100 # some basic mathematics being applied here

# %%
bachelor_percent # now we have the percentage, but it looks funky.
# Out:
# np.float64(16.45203921689154)

# %%
print(f"{bachelor_percent:.2f}% of the dataset has a Bachelor's degrees.") # i have no idea what this means
# Out:
# 16.45% of the dataset has a Bachelor's degrees.

# %%
Higher_edu = (adult_df['education'] == 'Bachelors','Masters','Doctorate') (adult_df['salary'] == '>50K').sum()
# Out:
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# C:\Users\Adewole\AppData\Local\Temp\ipykernel_6548\2487782365.py:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   Higher_edu = (adult_df['education'] == 'Bachelors','Masters','Doctorate') (adult_df['salary'] == '>50K').sum()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 Higher_edu = (adult_df['education'] == 'Bachelors','Masters','Doctorate') (adult_df['salary'] == '>50K').sum()
#
# TypeError: 'tuple' object is not callable

# %%
higher_edu = adult_df[adult_df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])] # this will check the values in a specific field

# %%
higher_edu_rich = higher_edu[higher_edu['salary'] == '>50K'] # this obviously creates a pandas series and specifies that it should return those that are in higher education and are worth over 50K a year.

# %%
higher_edu
# Out:
#                     age         workclass  fnlwgt  education  education_num  \
# race
# White                39         State-gov   77516  Bachelors             13
# White                50  Self-emp-not-inc   83311  Bachelors             13
# Black                28           Private  338409  Bachelors             13
# White                37           Private  284582    Masters             14
# White                31           Private   45781    Masters             14
# ...                 ...               ...     ...        ...            ...
# Black                38           Private  139180  Bachelors             13
# White                71               NaN  287372  Doctorate             16
# Other                31           Private  199655    Masters             14
# Asian-Pac-Islander   32           Private  116138    Masters             14
# White                53           Private  321865    Masters             14
#
# ...

# %%
higher_edu_rich
# Out:
#                     age         workclass  fnlwgt  education  education_num  \
# race
# White                31           Private   45781    Masters             14
# White                42           Private  159449  Bachelors             13
# Asian-Pac-Islander   30         State-gov  141297  Bachelors             13
# White                43  Self-emp-not-inc  292175    Masters             14
# White                40           Private  193524  Doctorate             16
# ...                 ...               ...     ...        ...            ...
# Asian-Pac-Islander   54           Private  337992  Bachelors             13
# White                34           Private  160216  Bachelors             13
# Black                38           Private  139180  Bachelors             13
# White                71               NaN  287372  Doctorate             16
# White                53           Private  321865    Masters             14
#
# ...

# %%
higher_education_rich = (len(higher_edu_rich) / len(higher_edu)) * 100 # len is a built in function used to return the numnber of items in an object

# %%
print(f"{higher_education_rich:.2f}% of people with higher education earn >50K")
# Out:
# 46.55% of people with higher education earn >50K

# %%
not_higher_edu = adult_df[adult_df['education'].isin(['Bachelors','Masters','Doctorate']) == False]

# %%
not_higher_edu_rich = not_higher_edu[not_higher_edu['salary'] == '>50K']

# %%
not_higher_edu_rich
# Out:
#                     age         workclass  fnlwgt     education  \
# race
# White                52  Self-emp-not-inc  209642       HS-grad
# Black                37           Private  280464  Some-college
# Asian-Pac-Islander   40           Private  121772     Assoc-voc
# Asian-Pac-Islander   54               NaN  180211  Some-college
# White                31           Private   84154  Some-college
# ...                 ...               ...     ...           ...
# White                57         Local-gov  110417       HS-grad
# White                46           Private  364548  Some-college
# White                39         Local-gov  111499    Assoc-acdm
# White                40           Private  154374       HS-grad
# White                52      Self-emp-inc  287927       HS-grad
#
#                     education_num      marital_status         occupation  \
# race
# White                           9  Married-civ-spouse    Exec-managerial
# ...

# %%
not_higher_edu
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# race
# White   38           Private  215646       HS-grad              9
# Black   53           Private  234721          11th              7
# Black   49           Private  160187           9th              5
# White   52  Self-emp-not-inc  209642       HS-grad              9
# Black   37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# White   27           Private  257302    Assoc-acdm             12
# White   40           Private  154374       HS-grad              9
# White   58           Private  151910       HS-grad              9
# White   22           Private  201490       HS-grad              9
# White   52      Self-emp-inc  287927       HS-grad              9
#
#               marital_status         occupation   relationship     sex  \
# race
# White               Divorced  Handlers-cleaners  Not-in-family    Male
# ...

# %%
lower_education_rich = (len(not_higher_edu_rich) / len(not_higher_edu)) * 100

# %%
print(f"{lower_education_rich:.2f}% Percentage without higher education that earn >50K")
# Out:
# 17.38% Percentage without higher education that earn >50K

# %%
adult_df['hours_per_week'].describe()
# Out:
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours_per_week, dtype: float64

# %%
min_work_hours = adult_df[adult_df['hours_per_week'] == 1 ]# in this case i have created a pandas series, that pulls the minimum work hours directly, also in this case '1' is incorrect add it as 1 instead

# %% [markdown]
# min_work_hours

# %%
min_work_hours # it says 1 hours a week, in this case which is of course incorrect, but the point of this course is to accomplish the tasks. Data cleaning can be done in our own time.
# Out:
#                     age         workclass  fnlwgt     education  \
# race
# White                58         State-gov  109567     Doctorate
# White                66      Self-emp-inc  150726           9th
# White                69               NaN  195779     Assoc-voc
# White                78               NaN  363134       HS-grad
# White                45               NaN  189564       Masters
# White                62               NaN   97231  Some-college
# White                76               NaN  211574          10th
# White                67               NaN  244122     Assoc-voc
# Asian-Pac-Islander   75               NaN  260543          10th
# White                27           Private  147951       HS-grad
# Asian-Pac-Islander   72               NaN   76860       HS-grad
# Asian-Pac-Islander   23           Private   72887       HS-grad
# White                65               NaN   76043       HS-grad
# White                77  Self-emp-not-inc   71676  Some-college
# ...

# %%
min_worker_rich  = min_work_hours[min_work_hours['salary'] == '>50K']

# %%
min_worker_rich
# Out:
#        age  workclass  fnlwgt  education  education_num      marital_status  \
# race
# White   58  State-gov  109567  Doctorate             16  Married-civ-spouse
# White   65        NaN   76043    HS-grad              9  Married-civ-spouse
#
#            occupation relationship   sex  capital_gain  capital_loss  \
# race
# White  Prof-specialty      Husband  Male             0             0
# White             NaN      Husband  Male             0             0
#
#        hours_per_week native_country salary
# race
# White               1  United-States   >50K
# White               1  United-States   >50K

# %%
rich_percentage = (len(min_worker_rich) / len(min_work_hours)) * 100

# %%
print(f"{rich_percentage:.2f}% Percentage of rich among those who work fewest hours that earn >50K")
# Out:
# 10.00% Percentage of rich among those who work fewest hours that earn >50K

# %%
#when it comes to finding out country with the highest amount of earners it is a different approach. To beging with.
#we look for the reach people only 
rich_people = adult_df[adult_df['salary'] == '>50K']

# %%
#then we know who our rich peeps are. moving forward, we need to sort them per country
rich_percentage_by_country = (rich_people['native_country'].value_counts() / adult_df['native_country'].value_counts()) * 100

# %%
highest_earning_country = rich_percentage_by_country.idxmax()

# %%
highest_percentage = rich_percentage_by_country.max()

# %%
print(f"{highest_earning_country} has the highest percentage of rich people at {highest_percentage:.2f}%.")
# Out:
# Iran has the highest percentage of rich people at 41.86%.

# %%
highest_earning_country
# Out:
# 'Iran'

# %%
highest_percentage
# Out:
# np.float64(41.86046511627907)

# %%
rich_people
# Out:
#                     age         workclass  fnlwgt     education  \
# race
# White                52  Self-emp-not-inc  209642       HS-grad
# White                31           Private   45781       Masters
# White                42           Private  159449     Bachelors
# Black                37           Private  280464  Some-college
# Asian-Pac-Islander   30         State-gov  141297     Bachelors
# ...                 ...               ...     ...           ...
# White                71               NaN  287372     Doctorate
# White                39         Local-gov  111499    Assoc-acdm
# White                53           Private  321865       Masters
# White                40           Private  154374       HS-grad
# White                52      Self-emp-inc  287927       HS-grad
#
#                     education_num      marital_status         occupation  \
# race
# White                           9  Married-civ-spouse    Exec-managerial
# ...

# %%
rich_people
# Out:
#                     age         workclass  fnlwgt     education  \
# race
# White                52  Self-emp-not-inc  209642       HS-grad
# White                31           Private   45781       Masters
# White                42           Private  159449     Bachelors
# Black                37           Private  280464  Some-college
# Asian-Pac-Islander   30         State-gov  141297     Bachelors
# ...                 ...               ...     ...           ...
# White                71               NaN  287372     Doctorate
# White                39         Local-gov  111499    Assoc-acdm
# White                53           Private  321865       Masters
# White                40           Private  154374       HS-grad
# White                52      Self-emp-inc  287927       HS-grad
#
#                     education_num      marital_status         occupation  \
# race
# White                           9  Married-civ-spouse    Exec-managerial
# ...

# %%
rich_percentage_by_country
# Out:
# native_country
# Cambodia                      36.842105
# Canada                        32.231405
# China                         26.666667
# Columbia                       3.389831
# Cuba                          26.315789
# Dominican-Republic             2.857143
# Ecuador                       14.285714
# El-Salvador                    8.490566
# England                       33.333333
# France                        41.379310
# Germany                       32.116788
# Greece                        27.586207
# Guatemala                      4.838710
# Haiti                          9.090909
# Holand-Netherlands                  NaN
# Honduras                       7.692308
# Hong                          30.000000
# Hungary                       23.076923
# India                         40.000000
# Iran                          41.860465
# Ireland                       20.833333
# Italy                         34.246575
# Jamaica                       12.345679
# ...

# %%
rich_people
# Out:
#                     age         workclass  fnlwgt     education  \
# race
# White                52  Self-emp-not-inc  209642       HS-grad
# White                31           Private   45781       Masters
# White                42           Private  159449     Bachelors
# Black                37           Private  280464  Some-college
# Asian-Pac-Islander   30         State-gov  141297     Bachelors
# ...                 ...               ...     ...           ...
# White                71               NaN  287372     Doctorate
# White                39         Local-gov  111499    Assoc-acdm
# White                53           Private  321865       Masters
# White                40           Private  154374       HS-grad
# White                52      Self-emp-inc  287927       HS-grad
#
#                     education_num      marital_status         occupation  \
# race
# White                           9  Married-civ-spouse    Exec-managerial
# ...

# %%
rich_indians = rich_people[rich_people['native_country'] == 'India']

# %%
top_IN_occupation = rich_indians['occupation'].value_counts().idxmax()

# %%
print(f"The most common high-paying occupation in India is: {top_IN_occupation}")
# Out:
# The most common high-paying occupation in India is: Prof-specialty
